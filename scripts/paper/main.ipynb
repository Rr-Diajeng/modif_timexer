# %%
# %%bash
#
# python3 -u ../../run.py \
#   --is_training 1 \
#   --task_name long_term_forecast \
#   --root_path /Users/rr/Documents/Diajeng/citi/timexer/TimeXer/dataset/forPaper \
#   --data_path ghi_kaohsiung_dsc2_2020.csv \
#   --model_id TimeXer_120_60 \
#   --model TimeXer \
#   --data custom \
#   --features MS \
#   --seq_len 120 \
#   --pred_len 60 \
#   --e_layers 3 \
#   --enc_in 3 \
#   --dec_in 3 \
#   --c_out 1 \
#   --train_epochs 1 \
#   --des Timexer-MS \
#   --patch_len 24 \
#   --d_model 512 \
#   --d_ff 512 \
#   --batch_size 4 \
#   --itr 1
# Out:
# False
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           TimeXer_120_60      Model:              TimeXer
#
# Data Loader
#   Data:               custom              Root Path:          /Users/rr/Documents/Diajeng/citi/timexer/TimeXer/dataset/forPaper
#   Data Path:          ghi_kaohsiung_dsc2_2020.csvFeatures:           MS
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            120                 Label Len:          48
#   Pred Len:           60                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             3                   Dec In:             3
#   C Out:              1                   d model:            512
#   n heads:            8                   e layers:           3
# ...
