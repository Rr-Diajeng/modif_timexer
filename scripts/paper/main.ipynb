# %%
data_path = "./ghi_kaohsiung_dsc2.csv"
des='Timexer-MS'
patch_len=24

# %%
# !python3 -u run.py \
  --is_training 1 \
  --task_name long_term_forecast \
  --root_path ./dataset/forPaper/ \
  --data_path ${data_path} \
  --model_id TimeXer_120_60 \
  --model TimeXer \
  --data custom \
  --features MS \
  --seq_len 120 \
  --pred_len 60 \
  --e_layers 3 \
  --enc_in 3 \
  --dec_in 3 \
  --c_out 1 \
  --des ${des} \
  --patch_len ${patch_len} \
  --d_model 512 \
  --d_ff 512 \
  --batch_size 4 \
  --itr 1
